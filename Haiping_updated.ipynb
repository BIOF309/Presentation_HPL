# %%
#load the libraries 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/haipingliu/Desktop/BiOF309/Final_project'

# %%
# Read CSV file
df = pd.read_csv('/Users/haipingliu/Desktop/BiOF309/Final_project/DEG_ anno.csv')

# %%
# Display how many genes are differentially expressed
df.shape
# Out:
# (3296, 7)

# %%
#Dispay column names
df.columns
# Out:
# Index(['Gene_ID', 'Gene_Annotation', 'amiR396_GF_FPKM', 'STTM396_GF_FPKM',
#        'Fold_change', 'p_value', 'q_value'],
#       dtype='object')

# %%
# Display how many genes have more than 2 folds change
data_fold = df['Fold_change']
data_qvalue = df['q_value']
fold_cutoff = 1
qvalue_cutoff = 0.05
number_of_genes = len(df.index)

filtered_ids = []
for i in range(0, number_of_genes):
    if (abs(data_fold[i]) >= fold_cutoff) and (data_qvalue[i] <= qvalue_cutoff):
        filtered_ids.append(i)
        
filtered = df.ix[filtered_ids,:]
print("Number of DE genes: ")
print(len(filtered.index))

filtered.head()
# Out:
# Number of DE genes:
# 3005
# /Users/haipingliu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if sys.path[0] == '':
#           Gene_ID                                    Gene_Annotation  \
# 0  Solyc04g076970                SUBFAMILY NOT NAMED (PTHR46354:SF1)
# 1  Solyc05g014280  26.5 KDA HEAT SHOCK PROTEIN, MITOCHONDRIAL (PT...
# 2  Solyc11g020330      22.0 KDA HEAT SHOCK PROTEIN (PTHR11527:SF135)
# 3  Solyc03g118060                SUBFAMILY NOT NAMED (PTHR33919:SF2)
# 4  Solyc11g045350               PROTEIN NLP8-RELATED (PTHR32002:SF7)
#
#    amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change       p_value       q_value
# 0          31.2004         0.035512     -9.77904  7.060000e-05  8.182710e-04
# ...

# %%
# Display how many genes have higher expression in STTM396 transgenic tomato Green fruits compared with amiR396
fold_cutoff = 1
qvalue_cutoff = 0.05
number_of_genes = len(df.index)

filtered_ids = []
for i in range(0, number_of_genes):
    if (data_fold[i] >= fold_cutoff) and (data_qvalue[i] <= qvalue_cutoff):
        filtered_ids.append(i)
        
filtered = df.ix[filtered_ids,:]
print("Number of DE genes: ")
print(len(filtered.index))

filtered.head()
# Out:
# Number of DE genes:
# 1812
# /Users/haipingliu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
#              Gene_ID                                    Gene_Annotation  \
# 1477  Solyc12g009560               SUBFAMILY NOT NAMED (PTHR13318:SF22)
# 1478  Solyc01g109880      BZIP TRANSCRIPTION FACTOR 11 (PTHR45764:SF12)
# 1479  Solyc04g081440               SUBFAMILY NOT NAMED (PTHR31916:SF15)
# 1480  Solyc02g083810  FERREDOXIN--NADP REDUCTASE, LEAF ISOZYME 1, CH...
# 1481  Solyc01g111920                SUBFAMILY NOT NAMED (PTHR47123:SF2)
#
#       amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change   p_value   q_value
# ...

# %%
# Display how many genes have lower expression in STTM396 transgenic tomato Green fruits compared with amiR396
fold_cutoff = 1
qvalue_cutoff = 0.05
number_of_genes = len(df.index)

filtered_ids = []
for i in range(0, number_of_genes):
    if (data_fold[i] < fold_cutoff) and (data_qvalue[i] <= qvalue_cutoff):
        filtered_ids.append(i)
        
filtered = df.ix[filtered_ids,:]
print("Number of DE genes: ")
print(len(filtered.index))

filtered.head()
# Out:
# Number of DE genes:
# 1469
# /Users/haipingliu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
#           Gene_ID                                    Gene_Annotation  \
# 0  Solyc04g076970                SUBFAMILY NOT NAMED (PTHR46354:SF1)
# 1  Solyc05g014280  26.5 KDA HEAT SHOCK PROTEIN, MITOCHONDRIAL (PT...
# 2  Solyc11g020330      22.0 KDA HEAT SHOCK PROTEIN (PTHR11527:SF135)
# 3  Solyc03g118060                SUBFAMILY NOT NAMED (PTHR33919:SF2)
# 4  Solyc11g045350               PROTEIN NLP8-RELATED (PTHR32002:SF7)
#
#    amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change       p_value       q_value
# 0          31.2004         0.035512     -9.77904  7.060000e-05  8.182710e-04
# ...

# %%
# RNA-seq result follows standard normal distribution (histogram)
data_fold = df['Fold_change']
plt.hist(data_fold,
        bins=100,
        density = True,
        alpha=1,
        color='steelblue',
        edgecolor='darkblue')
plt.xlabel('Fold_change_log2')
plt.ylabel('Gene_density')
plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

#plt.scatter(), x = 'a'; y ='b', c='c', s='d', data= data, alpha = 0.6 #alpha for transparency, c is for color, s is for bubble size
plt.scatter('a','b',
            c='c',
            s='d',
            data= data,
            alpha=0.6)
#plt.xlabel('a') #plt.ylabel('b') #plt.colorbar();  #show color scale #plt.show()
plt.xlabel('a')
plt.ylabel('b')
plt.colorbar()
plt.show()

# %%
#Volcano plot
newdf.plot(kind='scatter',
           x='log2FoldChange', 
           y='-log10padj', color = 'k')
plt.title("Volcano Plot")
plt.xlabel('log2 Fold Change in Expression')
plt.ylabel('-log10 Adjusted pvalue')
plt.axis([-2,2, 0, 15])
plt.show()

# %%
p1=sns.kdeplot(data_fold, shade=True, label = 'DEG Distribution')
plt.legend(loc='upper left')
plt.xlabel('Fold_change')
plt.ylabel('Gene_density')
plt.show()

# %%
# plot a volcano image
df_vol = df.loc[:,['Gene_ID','Fold_change','p_value']]
df_vol.head()
# Out:
#           Gene_ID  Fold_change       p_value
# 0  Solyc04g076970     -9.77904  7.060000e-05
# 1  Solyc05g014280     -9.21502  0.000000e+00
# 2  Solyc11g020330     -7.96676  0.000000e+00
# 3  Solyc03g118060     -7.70020  3.990000e-13
# 4  Solyc11g045350     -7.29059  2.240000e-05

# %%
# creat log10 value for p_value and append it to the df_vol
df_vol['-log10p_value'] = np.log10(1/df['p_value'])
df_vol.head()
# Out:
#           Gene_ID  Fold_change       p_value  -log10p_value
# 0  Solyc04g076970     -9.77904  7.060000e-05       4.151195
# 1  Solyc05g014280     -9.21502  0.000000e+00            inf
# 2  Solyc11g020330     -7.96676  0.000000e+00            inf
# 3  Solyc03g118060     -7.70020  3.990000e-13      12.399027
# 4  Solyc11g045350     -7.29059  2.240000e-05       4.649752

# %%
# Add volcano graphical image of the data here - Fold_change to -log10p_value

df_vol.plot(kind='scatter',
           x='Fold_change', 
           y='-log10p_value', color = 'c')
plt.title("Volcano Plot")
plt.xlabel('log2 Fold Change in Expression')
plt.ylabel('-log10 Adjusted pvalue')
plt.axis([-10,10, 0, 18])
plt.show()

# %%
# Extract gene annotation containing 'SUGAR'
Sugar = df[df['Gene_Annotation'].str.contains("SUGAR")]
Sugar
# Out:
#              Gene_ID                                    Gene_Annotation  \
# 279   Solyc12g010440        SUGAR PHOSPHATE EXCHANGER 3 (PTHR43184:SF7)
# 2083  Solyc07g006970        SUGAR TRANSPORT PROTEIN 7 (PTHR23500:SF353)
# 2468  Solyc04g058070        UDP-SUGAR PYROPHOSPHORYLASE (PTHR11952:SF9)
# 2658  Solyc09g074230    SUGAR TRANSPORTER ERD6-LIKE 7 (PTHR23500:SF112)
# 2832  Solyc03g097870  BIDIRECTIONAL SUGAR TRANSPORTER SWEET11-RELATE...
# 3243  Solyc01g098490  SUGAR TRANSPORTER ERD6-LIKE 1-RELATED (PTHR235...
#
#       amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change       p_value   q_value
# 279         13.708300          2.00971     -2.76999  3.270000e-07  0.000007
# 2083         4.791070         13.92610      1.53937  1.194860e-04  0.001285
# 2468         0.375429          1.46767      1.96692  1.048290e-02  0.049086
# 2658         0.549077          2.64168      2.26638  1.444620e-03  0.010410
# 2832         2.086680         13.75580      2.72076  1.200000e-06  0.000023
# ...

# %%
# Extract gene annotation containing 'STARCH'
Starch = df[df['Gene_Annotation'].str.contains("STARCH")]
Starch
# Out:
#              Gene_ID                                    Gene_Annotation  \
# 1469  Solyc02g080570  STARCH SYNTHASE 3, CHLOROPLASTIC/AMYLOPLASTIC ...
# 1489  Solyc02g088000  STARCH SYNTHASE 2, CHLOROPLASTIC/AMYLOPLASTIC ...
# 2484  Solyc02g071040  STARCH SYNTHASE 4, CHLOROPLASTIC/AMYLOPLASTIC-...
# 2758  Solyc03g083090  STARCH SYNTHASE 1, CHLOROPLASTIC/AMYLOPLASTIC ...
#
#       amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change       p_value  \
# 1469          7.82549          15.5866     0.994051  2.089220e-03
# 1489          6.57896          13.2388     1.008840  3.236250e-03
# 2484          4.70779          18.6810     1.988450  5.980000e-09
# 2758         28.78270         161.6350     2.489470  8.660000e-15
#
#            q_value
# 1469  1.389990e-02
# 1489  1.979860e-02
# 2484  1.930000e-07
# 2758  7.830000e-13

# %%
# Extract gene annotation containing 'SUCROSE'
Sucrose = df[df['Gene_Annotation'].str.contains("SUCROSE")]
Sucrose
# Out:
#              Gene_ID                                    Gene_Annotation  \
# 768   Solyc11g017010  SUCROSE TRANSPORT PROTEIN SUC1-RELATED (PTHR19...
# 1308  Solyc07g042550         SUCROSE SYNTHASE 1-RELATED (PTHR45839:SF3)
# 1686  Solyc07g007930  GALACTINOL--SUCROSE GALACTOSYLTRANSFERASE 6-RE...
# 2066  Solyc09g098590                 SUCROSE SYNTHASE 3 (PTHR45839:SF7)
# 2164  Solyc03g058970  GALACTINOL--SUCROSE GALACTOSYLTRANSFERASE 2-RE...
# 2518  Solyc10g081660      SUCROSE-PHOSPHATASE 1-RELATED (PTHR46521:SF4)
# 3154  Solyc07g065980  GALACTINOL--SUCROSE GALACTOSYLTRANSFERASE 1-RE...
# 3216  Solyc03g098290                 SUCROSE SYNTHASE 6 (PTHR45839:SF4)
#
#       amiR396_GF_FPKM  STTM396_GF_FPKM  Fold_change       p_value  \
# 768         25.058500          8.75030    -1.517890  5.390000e-05
# 1308        48.505500         27.60700    -0.813116  8.762820e-03
# 1686        43.785800         98.79340     1.173950  2.309920e-04
# ...

# %%
# Combine the gene list of the above three：'Sugar, Starch, Sucrose'
Sugar_gene= pd.concat([Sugar, Starch, Sucrose])
Sugar_gene
# Out:
#              Gene_ID                                    Gene_Annotation  \
# 279   Solyc12g010440        SUGAR PHOSPHATE EXCHANGER 3 (PTHR43184:SF7)
# 2083  Solyc07g006970        SUGAR TRANSPORT PROTEIN 7 (PTHR23500:SF353)
# 2468  Solyc04g058070        UDP-SUGAR PYROPHOSPHORYLASE (PTHR11952:SF9)
# 2658  Solyc09g074230    SUGAR TRANSPORTER ERD6-LIKE 7 (PTHR23500:SF112)
# 2832  Solyc03g097870  BIDIRECTIONAL SUGAR TRANSPORTER SWEET11-RELATE...
# 3243  Solyc01g098490  SUGAR TRANSPORTER ERD6-LIKE 1-RELATED (PTHR235...
# 1469  Solyc02g080570  STARCH SYNTHASE 3, CHLOROPLASTIC/AMYLOPLASTIC ...
# 1489  Solyc02g088000  STARCH SYNTHASE 2, CHLOROPLASTIC/AMYLOPLASTIC ...
# 2484  Solyc02g071040  STARCH SYNTHASE 4, CHLOROPLASTIC/AMYLOPLASTIC-...
# 2758  Solyc03g083090  STARCH SYNTHASE 1, CHLOROPLASTIC/AMYLOPLASTIC ...
# 768   Solyc11g017010  SUCROSE TRANSPORT PROTEIN SUC1-RELATED (PTHR19...
# 1308  Solyc07g042550         SUCROSE SYNTHASE 1-RELATED (PTHR45839:SF3)
# ...

# %%
# write a CSV file from DataFrame
Sugar_gene.to_csv('Sugar_gene.csv')

# %%
#Get targeted colums (FPKM values for two samples) from "Sugar_gene"
df_FPKM = Sugar_gene[['Gene_ID','amiR396_GF_FPKM','STTM396_GF_FPKM']]
df_FPKM
# Out:
#              Gene_ID  amiR396_GF_FPKM  STTM396_GF_FPKM
# 279   Solyc12g010440        13.708300          2.00971
# 2083  Solyc07g006970         4.791070         13.92610
# 2468  Solyc04g058070         0.375429          1.46767
# 2658  Solyc09g074230         0.549077          2.64168
# 2832  Solyc03g097870         2.086680         13.75580
# 3243  Solyc01g098490         0.045424          1.67885
# 1469  Solyc02g080570         7.825490         15.58660
# 1489  Solyc02g088000         6.578960         13.23880
# 2484  Solyc02g071040         4.707790         18.68100
# 2758  Solyc03g083090        28.782700        161.63500
# 768   Solyc11g017010        25.058500          8.75030
# 1308  Solyc07g042550        48.505500         27.60700
# 1686  Solyc07g007930        43.785800         98.79340
# 2066  Solyc09g098590         1.089560          3.12340
# 2164  Solyc03g058970        20.977200         65.11940
# 2518  Solyc10g081660         3.626360         14.95220
# ...

# %%
df_FPKM_index = df_FPKM.set_index('Gene_ID')
df_FPKM_index
# Out:
#                 amiR396_GF_FPKM  STTM396_GF_FPKM
# Gene_ID
# Solyc12g010440        13.708300          2.00971
# Solyc07g006970         4.791070         13.92610
# Solyc04g058070         0.375429          1.46767
# Solyc09g074230         0.549077          2.64168
# Solyc03g097870         2.086680         13.75580
# Solyc01g098490         0.045424          1.67885
# Solyc02g080570         7.825490         15.58660
# Solyc02g088000         6.578960         13.23880
# Solyc02g071040         4.707790         18.68100
# Solyc03g083090        28.782700        161.63500
# Solyc11g017010        25.058500          8.75030
# Solyc07g042550        48.505500         27.60700
# Solyc07g007930        43.785800         98.79340
# Solyc09g098590         1.089560          3.12340
# Solyc03g058970        20.977200         65.11940
# Solyc10g081660         3.626360         14.95220
# Solyc07g065980         0.565749         10.59300
# Solyc03g098290         0.168017          5.01306

# %%
#Heatmap for expression of sweetness-related genes
df_FPKM_index = df_FPKM.set_index('Gene_ID')
sns.clustermap(df_FPKM_index,
              z_score=1,
              metric="euclidean",
              method="ward",
              cmap="Blues",
              annot=True,
              linewidths=1.0)
plt.show()
